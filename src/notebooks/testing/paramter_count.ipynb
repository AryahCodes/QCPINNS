# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import os
import torch
import matplotlib.pyplot as plt

# %%
from src.utils.logger import Logging
from src.testing.helmholtz_test import load_model
from src.utils.error_metrics import lp_error

# %%
log_path = "./testing_checkpoints"
logger = Logging(log_path)
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Load trained models of the Helmhotlz equation

# %%
# model_dir = "models/2025-02-06_19-28-34-814985"  # cascade
BASE_PATH = "/models/helmholtz"

MODEL_PATHS = {
    f"{BASE_PATH}/2025-02-12_16-33-22-249802": ("DV", "angle_layered"),
    f"{BASE_PATH}/model_cascade.pth": ("DV", "angle_cascade"),
    f"{BASE_PATH}/2025-02-06_19-32-04-408294": ("DV", "angle_cross_mesh"),
    f"{BASE_PATH}/2025-02-06_19-25-14-069609": ("DV", "angle_alternate"),
    f"{BASE_PATH}/2025-02-12_16-33-59-543343": ("DV", "amp_layered"),
    f"{BASE_PATH}/2025-02-06_18-54-03-851796": ("DV", "amp_alternate"),
    f"{BASE_PATH}/2025-02-06_18-52-46-865258": ("DV", "amp_cross_mesh"),
    f"{BASE_PATH}/2025-02-06_18-48-39-607215": ("DV", "amp_cascade"),
    f"{BASE_PATH}/2025-02-06_18-10-42-119955": ("CV", "cv"),
    f"{BASE_PATH}/2025-02-09_20-05-25-094982": ("CV", "gcv"),
    f"{BASE_PATH}/2025-02-09_00-01-28-238904": ("Classical", "classical"),
}

# %%
for model_path, (solver_type, model_name) in MODEL_PATHS.items():
    try:
        model, state = load_model(model_path, solver_type, logger)
        model.logger = logger
        logger.print("******************************\n")
        logger.print(f"\nProcessing model: {model_name}")
        logger.print(f"classic_network: {state['args']['classic_network']}")
        if model_name != "classical":
            logger.print(f"num_qubits: {state['args']['num_qubits']}")
            logger.print(f"num_quantum_layers: {state['args']['num_quantum_layers']}")
        total_params = sum(p.numel() for p in model.parameters())
        logger.print(f"Total number of parameters: {total_params}")

        logger.print(f"Method used: {model_name}")
        logger.print(f"Total iterations: {len(state['loss_history'])}")
        if state["loss_history"]:
            logger.print(f"Final loss: {state['loss_history'][-1]}")

        logger.print(f"File directory: {model_path}")

    except Exception as e:
        logger.print(f"Error processing model {model_name}: {e}")
        continue
    finally:
        if "model" in locals():
            del model
# Out:
# INFO:src.utils.logger:Error processing model angle_layered: local variable 'model' referenced before assignment
# INFO:src.utils.logger:Error processing model angle_cascade: local variable 'model' referenced before assignment
# INFO:src.utils.logger:Error processing model angle_cross_mesh: local variable 'model' referenced before assignment
# INFO:src.utils.logger:Error processing model angle_alternate: local variable 'model' referenced before assignment
# INFO:src.utils.logger:Error processing model amp_layered: local variable 'model' referenced before assignment
# INFO:src.utils.logger:Error processing model amp_alternate: local variable 'model' referenced before assignment
# INFO:src.utils.logger:Error processing model amp_cross_mesh: local variable 'model' referenced before assignment
# INFO:src.utils.logger:Error processing model amp_cascade: local variable 'model' referenced before assignment
# INFO:src.utils.logger:Using CVNeuralNetwork1
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:
# Processing model: cv
# INFO:src.utils.logger:classic_network: [2, 50, 1]
# INFO:src.utils.logger:num_qubits: 2
# INFO:src.utils.logger:num_quantum_layers: 1
# INFO:src.utils.logger:Total number of parameters: 469
# INFO:src.utils.logger:Method used: cv
# INFO:src.utils.logger:Total iterations: 20000
# INFO:src.utils.logger:Final loss: 5077.79541015625
# INFO:src.utils.logger:File directory: ./models/helmholtz_amplitude/2025-02-06_18-10-42-119955
# INFO:src.utils.logger:Using CVNeuralNetwork3
# INFO:src.utils.logger:Error loading model from ./models/helmholtz_amplitude/2025-02-09_20-05-25-094982: Error(s) in loading state_dict for CVNeuralNetwork3:
# 	Missing key(s) in state_dict: "squeezing_r", "squeezing_phi", "displacement_r", "displacement_phi", "cubic_phase", "cross_kerr", "input_scaling", "input_phase".
# INFO:src.utils.logger:Error processing model gcv: Error(s) in loading state_dict for CVNeuralNetwork3:
# 	Missing key(s) in state_dict: "squeezing_r", "squeezing_phi", "displacement_r", "displacement_phi", "cubic_phase", "cross_kerr", "input_scaling", "input_phase".
# INFO:src.utils.logger:checkpoint path: self.log_path='./testing_checkpoints/2025-10-13_09-44-18-477748'
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:
# Processing model: classical
# INFO:src.utils.logger:classic_network: [2, 50, 1]
# INFO:src.utils.logger:Total number of parameters: 2751
# INFO:src.utils.logger:Method used: classical
# INFO:src.utils.logger:Total iterations: 20000
# INFO:src.utils.logger:Final loss: 6.134862422943115
# INFO:src.utils.logger:File directory: ./models/helmholtz_amplitude/2025-02-09_00-01-28-238904
# Model state loaded from ./models/helmholtz_amplitude/2025-02-09_00-01-28-238904/model.pth
